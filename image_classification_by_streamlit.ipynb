# %% [markdown]
# <a href="https://colab.research.google.com/github/showtender1/-/blob/main/image_classification_by_streamlit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install streamlit -q
# !pip install pyngrok
# Out:
# Requirement already satisfied: pyngrok in /usr/local/lib/python3.10/dist-packages (7.1.6)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.10/dist-packages (from pyngrok) (6.0.1)

# %%
from pyngrok import ngrok
ngrok.set_auth_token('2jKr3OhthBNZOyWrnqmhsSLuXjq_7eGq5YW2Dd9FK73X4Xjhk')

# %%
# %%writefile app.py

import streamlit as st
import tensorflow as tf
from PIL import Image, ImageOps
import numpy as np
from tensorflow.keras.applications.imagenet_utils import decode_predictions

resnet50_pre = tf.keras.applications.resnet50.ResNet50(weights='imagenet', input_shape=(224,224.3))

st.title('이미지 분류 인공지능 웹페이지')
file = st.file_uploader('이미지를 올려주세요.', type=['jpg', 'png'])

if file is None:
    st.text('이미지를 올려주세요.')
else:
    image = Image.open(file)
    st.image(image, use_column_width=True)
    img_resized = ImageOps.fit(image, (224, 224), Image.ANTIALIAS)
    img_resized = img_resized.convert("RGB")
    img_resized = np.asarray(img_resized)

pred = resnet50_pre.predict(img_resized.reshape[1,224,224,3])
decode_pred = decode_predictions(pred)
results = ''
for i, instance in enumerate(decode_pred[0]):
  results += '{}위: {} ({:.2f}%) '.format(i+1, instance[1], instance[2]*100)
st.success(results)
# Out:
# Writing app.py

# %%
# !ls
# Out:
# app.py	sample_data

# %%
# !cat app.py
# Out:
# import streamlit as st
# import tensorflow as tf
# from PIL import Image, ImageOps
# import numpy as np
# from tensorflow.keras.applications.imagenet_utils import decode_predictions
#
# resnet50_pre = tf.keras.applications.resnet50.ResNet50(weights='imagenet', input_shape=(224,224.3))
#
# st.title('이미지 분류 인공지능 웹페이지')
# file = st.file_uploader('이미지를 올려주세요.', type=['jpg', 'png'])
#
# if file is None:
#     st.text('이미지를 올려주세요.')
# else:
#     image = Image.open(file)
#     st.image(image, use_column_width=True)
#     img_resized = ImageOps.fit(image, (224, 224), Image.ANTIALIAS)
#     img_resized = img_resized.convert("RGB")
#     img_resized = np.asarray(img_resized)
#
# pred = resnet50_pre.predict(img_resized.reshape[1,224,224,3])
# decode_pred = decode_predictions(pred)
# results = ''
# for i, instance in enumerate(decode_pred[0]):
#   results += '{}위: {} ({:.2f}%) '.format(i+1, instance[1], instance[2]*100)
# st.success(results)

# %%
# !nohup streamlit run app.py --server.port 80 &
# Out:
# nohup: appending output to 'nohup.out'

# %%
url = ngrok.connect(port='80')
url
# Out:
# WARNING:pyngrok.process.ngrok:t=2024-07-16T16:40:49+0000 lvl=warn msg="invalid tunnel configuration" pg=/api/tunnels id=3e988f6ce061cb46 err="yaml: unmarshal errors:\n  line 1: field port not found in type config.HTTPv2Tunnel"
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pyngrok/ngrok.py in api_request(url, method, data, params, timeout, auth)
#     517     try:
# --> 518         response = urlopen(request, encoded_data, timeout)
#     519         response_data = response.read().decode("utf-8")
#
# /usr/lib/python3.10/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     215         opener = _opener
# --> 216     return opener.open(url, data, timeout)
#     217
#
# /usr/lib/python3.10/urllib/request.py in open(self, fullurl, data, timeout)
#     524             meth = getattr(processor, meth_name)
# --> 525             response = meth(req, response)
#     526
#
# /usr/lib/python3.10/urllib/request.py in http_response(self, request, response)
#     633         if not (200 <= code < 300):
# --> 634             response = self.parent.error(
#     635                 'http', request, response, code, msg, hdrs)
#
# /usr/lib/python3.10/urllib/request.py in error(self, proto, *args)
#     562             args = (dict, 'default', 'http_error_default') + orig_args
# --> 563             return self._call_chain(*args)
#     564
#
# /usr/lib/python3.10/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     495             func = getattr(handler, meth_name)
# --> 496             result = func(*args)
#     497             if result is not None:
#
# /usr/lib/python3.10/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     642     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     644
#
# HTTPError: HTTP Error 400: Bad Request
#
# During handling of the above exception, another exception occurred:
#
# PyngrokNgrokHTTPError                     Traceback (most recent call last)
# <ipython-input-14-2020b1cbcc3d> in <cell line: 1>()
# ----> 1 url = ngrok.connect(port='80')
#       2 url
#
# /usr/local/lib/python3.10/dist-packages/pyngrok/ngrok.py in connect(addr, proto, name, pyngrok_config, **options)
#     318     logger.debug(f"Creating tunnel with options: {options}")
#     319
# --> 320     tunnel = NgrokTunnel(api_request(f"{api_url}/api/tunnels", method="POST", data=options,
#     321                                      timeout=pyngrok_config.request_timeout),
#     322                          pyngrok_config, api_url)
#
# /usr/local/lib/python3.10/dist-packages/pyngrok/ngrok.py in api_request(url, method, data, params, timeout, auth)
#     537         logger.debug(f"Response {status_code}: {response_data.strip()}")
#     538
# --> 539         raise PyngrokNgrokHTTPError(f"ngrok client exception, API returned {status_code}: {response_data}",
#     540                                     e.url,
#     541                                     status_code, e.reason, e.headers, response_data)
#
# PyngrokNgrokHTTPError: ngrok client exception, API returned 400: {"error_code":102,"status_code":400,"msg":"invalid tunnel configuration","details":{"err":"yaml: unmarshal errors:\n  line 1: field port not found in type config.HTTPv2Tunnel"}}

# %%
rm -rf ~/.ngrok2

# %%
# !pip install streamlit -q
# !pip install pyngrok

from pyngrok import ngrok
ngrok.set_auth_token('2jKr3OhthBNZOyWrnqmhsSLuXjq_7eGq5YW2Dd9FK73X4Xjhk')

# %%writefile app.py

import streamlit as st
import tensorflow as tf
from PIL import Image, ImageOps
import numpy as np
from tensorflow.keras.applications.imagenet_utils import decode_predictions
from pyngrok import ngrok  # pyngrok을 임포트

resnet50_pre = tf.keras.applications.resnet50.ResNet50(weights='imagenet', input_shape=(224,224,3))

st.title('이미지 분류 인공지능 웹페이지')
file = st.file_uploader('이미지를 올려주세요.', type=['jpg', 'png'])

if file is None:
    st.text('이미지를 올려주세요.')
else:
    image = Image.open(file)
    st.image(image, use_column_width=True)
    img_resized = ImageOps.fit(image, (224, 224), Image.ANTIALIAS)
    img_resized = img_resized.convert("RGB")
    img_resized = np.asarray(img_resized)

pred = resnet50_pre.predict(img_resized.reshape(1,224,224,3))
decode_pred = decode_predictions(pred)
results = ''
for i, instance in enumerate(decode_pred[0]):
    results += '{}위: {} ({:.2f}%) '.format(i+1, instance[1], instance[2]*100)
st.success(results)

# nohup 명령어를 사용하여 Streamlit 애플리케이션을 백그라운드에서 실행
# !nohup streamlit run app.py --server.port 80 &

# ngrok을 사용하여 외부에서 접속할 수 있는 URL을 생성
public_url = ngrok.connect(port='80')
public_url
# Out:
# Requirement already satisfied: pyngrok in /usr/local/lib/python3.10/dist-packages (7.1.6)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.10/dist-packages (from pyngrok) (6.0.1)
# UsageError: Line magic function `%%writefile` not found.

# %%
# 먼저 필요한 패키지를 설치합니다.
# !pip install streamlit -q
# !pip install pyngrok

# ngrok 토큰을 설정합니다.
from pyngrok import ngrok
ngrok.set_auth_token('2jKr3OhthBNZOyWrnqmhsSLuXjq_7eGq5YW2Dd9FK73X4Xjhk')
# Out:
# Requirement already satisfied: pyngrok in /usr/local/lib/python3.10/dist-packages (7.1.6)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.10/dist-packages (from pyngrok) (6.0.1)

# %%
# %%writefile app.py
import streamlit as st
import tensorflow as tf
from PIL import Image, ImageOps
import numpy as np
from tensorflow.keras.applications.imagenet_utils import decode_predictions

resnet50_pre = tf.keras.applications.resnet50.ResNet50(weights='imagenet', input_shape=(224,224,3))

st.title('이미지 분류 인공지능 웹페이지')
file = st.file_uploader('이미지를 올려주세요.', type=['jpg', 'png'])

if file is None:
    st.text('이미지를 올려주세요.')
else:
    image = Image.open(file)
    st.image(image, use_column_width=True)
    img_resized = ImageOps.fit(image, (224, 224), Image.ANTIALIAS)
    img_resized = img_resized.convert("RGB")
    img_resized = np.asarray(img_resized)

    pred = resnet50_pre.predict(img_resized.reshape(1,224,224,3))
    decode_pred = decode_predictions(pred)
    results = ''
    for i, instance in enumerate(decode_pred[0]):
        results += '{}위: {} ({:.2f}%) '.format(i+1, instance[1], instance[2]*100)
    st.success(results)
# Out:
# Overwriting app.py

# %%
# !nohup streamlit run app.py --server.port 80 &
# Out:
# nohup: appending output to 'nohup.out'

# %%
url = ngrok.connect(port='80')
url
# Out:
# WARNING:pyngrok.process.ngrok:t=2024-07-16T16:47:45+0000 lvl=warn msg="invalid tunnel configuration" pg=/api/tunnels id=92eb803db768f8b4 err="yaml: unmarshal errors:\n  line 1: field port not found in type config.HTTPv2Tunnel"
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pyngrok/ngrok.py in api_request(url, method, data, params, timeout, auth)
#     517     try:
# --> 518         response = urlopen(request, encoded_data, timeout)
#     519         response_data = response.read().decode("utf-8")
#
# /usr/lib/python3.10/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     215         opener = _opener
# --> 216     return opener.open(url, data, timeout)
#     217
#
# /usr/lib/python3.10/urllib/request.py in open(self, fullurl, data, timeout)
#     524             meth = getattr(processor, meth_name)
# --> 525             response = meth(req, response)
#     526
#
# /usr/lib/python3.10/urllib/request.py in http_response(self, request, response)
#     633         if not (200 <= code < 300):
# --> 634             response = self.parent.error(
#     635                 'http', request, response, code, msg, hdrs)
#
# /usr/lib/python3.10/urllib/request.py in error(self, proto, *args)
#     562             args = (dict, 'default', 'http_error_default') + orig_args
# --> 563             return self._call_chain(*args)
#     564
#
# /usr/lib/python3.10/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     495             func = getattr(handler, meth_name)
# --> 496             result = func(*args)
#     497             if result is not None:
#
# /usr/lib/python3.10/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     642     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     644
#
# HTTPError: HTTP Error 400: Bad Request
#
# During handling of the above exception, another exception occurred:
#
# PyngrokNgrokHTTPError                     Traceback (most recent call last)
# <ipython-input-20-2020b1cbcc3d> in <cell line: 1>()
# ----> 1 url = ngrok.connect(port='80')
#       2 url
#
# /usr/local/lib/python3.10/dist-packages/pyngrok/ngrok.py in connect(addr, proto, name, pyngrok_config, **options)
#     318     logger.debug(f"Creating tunnel with options: {options}")
#     319
# --> 320     tunnel = NgrokTunnel(api_request(f"{api_url}/api/tunnels", method="POST", data=options,
#     321                                      timeout=pyngrok_config.request_timeout),
#     322                          pyngrok_config, api_url)
#
# /usr/local/lib/python3.10/dist-packages/pyngrok/ngrok.py in api_request(url, method, data, params, timeout, auth)
#     537         logger.debug(f"Response {status_code}: {response_data.strip()}")
#     538
# --> 539         raise PyngrokNgrokHTTPError(f"ngrok client exception, API returned {status_code}: {response_data}",
#     540                                     e.url,
#     541                                     status_code, e.reason, e.headers, response_data)
#
# PyngrokNgrokHTTPError: ngrok client exception, API returned 400: {"error_code":102,"status_code":400,"msg":"invalid tunnel configuration","details":{"err":"yaml: unmarshal errors:\n  line 1: field port not found in type config.HTTPv2Tunnel"}}

# %%
# 먼저 필요한 패키지를 설치합니다.
# !pip install streamlit -q
# !pip install pyngrok
# Out:
# Requirement already satisfied: pyngrok in /usr/local/lib/python3.10/dist-packages (7.1.6)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.10/dist-packages (from pyngrok) (6.0.1)

# %%
# ngrok 토큰을 설정합니다.
from pyngrok import ngrok
ngrok.set_auth_token('2jKr3OhthBNZOyWrnqmhsSLuXjq_7eGq5YW2Dd9FK73X4Xjhk')

# %%
# %%writefile app.py
import streamlit as st
import tensorflow as tf
from PIL import Image, ImageOps
import numpy as np
from tensorflow.keras.applications.imagenet_utils import decode_predictions

resnet50_pre = tf.keras.applications.resnet50.ResNet50(weights='imagenet', input_shape=(224,224,3))

st.title('이미지 분류 인공지능 웹페이지')
file = st.file_uploader('이미지를 올려주세요.', type=['jpg', 'png'])

if file is None:
    st.text('이미지를 올려주세요.')
else:
    image = Image.open(file)
    st.image(image, use_column_width=True)
    img_resized = ImageOps.fit(image, (224, 224), Image.ANTIALIAS)
    img_resized = img_resized.convert("RGB")
    img_resized = np.asarray(img_resized)

    pred = resnet50_pre.predict(img_resized.reshape(1,224,224,3))
    decode_pred = decode_predictions(pred)
    results = ''
    for i, instance in enumerate(decode_pred[0]):
        results += '{}위: {} ({:.2f}%) '.format(i+1, instance[1], instance[2]*100)
    st.success(results)
# Out:
# Overwriting app.py

# %%
# !nohup streamlit run app.py --server.port 80 &
# Out:
# nohup: appending output to 'nohup.out'

# %%
# ngrok을 사용하여 외부에서 접속할 수 있는 URL을 생성합니다.
public_url = ngrok.connect(80)
print("Streamlit 앱에 접근하려면 이 URL을 사용하세요:", public_url)
# Out:
# Streamlit 앱에 접근하려면 이 URL을 사용하세요: NgrokTunnel: "https://3b41-34-23-217-86.ngrok-free.app" -> "http://localhost:80"
